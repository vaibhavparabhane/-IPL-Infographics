# %%
# Importing pandas for data manipulation
import pandas as pd

# %%
# Load the CSV file into a DataFrame
df=pd.read_csv('/content/matches.csv')

# %%
# Display the contents of the DataFrame
df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
# Display the first 5 rows of the DataFrame
df.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
# Display the last 5 rows of the DataFrame
df.tail()
# Out:
#            id season       city        date   match_type  player_of_match  \
# 1090  1426307   2024  Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309   2024  Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310   2024  Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311   2024    Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312   2024    Chennai  2024-05-26        Final         MA Starc
#
#                                                   venue  \
# 1090  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1091                   Narendra Modi Stadium, Ahmedabad
# 1092                   Narendra Modi Stadium, Ahmedabad
# 1093           MA Chidambaram Stadium, Chepauk, Chennai
# 1094           MA Chidambaram Stadium, Chepauk, Chennai
#
#                             team1                  team2          toss_winner  \
# 1090                 Punjab Kings    Sunrisers Hyderabad         Punjab Kings
# ...

# %%
# Replace 'Royal Challengers Bengaluru' with 'RCB'
df.replace('Royal Challengers Bengaluru','RCB',inplace=True)
df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
# Display the data types of each column
df.dtypes
# Out:
# id                   int64
# season              object
# city                object
# date                object
# match_type          object
# player_of_match     object
# venue               object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# winner              object
# result              object
# result_margin      float64
# target_runs        float64
# target_overs       float64
# super_over          object
# umpire1             object
# umpire2             object
# dtype: object

# %%
# Display a summary of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
# ...

# %%
# Get summary statistics for numerical columns
df.describe()
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.095000e+03    1076.000000  1092.000000   1092.000000
# mean   9.048283e+05      17.259294   165.684066     19.759341
# std    3.677402e+05      21.787444    33.427048      1.581108
# min    3.359820e+05       1.000000    43.000000      5.000000
# 25%    5.483315e+05       6.000000   146.000000     20.000000
# 50%    9.809610e+05       8.000000   166.000000     20.000000
# 75%    1.254062e+06      20.000000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %%
# Get summary statistics for the 'toss_decision' column
df['toss_decision'].describe()
# Out:
# count      1095
# unique        2
# top       field
# freq        704
# Name: toss_decision, dtype: object

# %%
 # Get summary statistics for categorical (object) columns
df.describe(include='object')
# Out:
#        season    city        date match_type player_of_match         venue  \
# count    1095    1044        1095       1095            1090          1095
# unique     17      36         823          8             291            58
# top      2013  Mumbai  2017-04-09     League  AB de Villiers  Eden Gardens
# freq       76     173           2       1029              25            77
#
#                               team1           team2     toss_winner  \
# count                          1095            1095            1095
# unique                           19              19              19
# top     Royal Challengers Bangalore  Mumbai Indians  Mumbai Indians
# freq                            135             138             143
#
#        toss_decision          winner   result super_over method       umpire1  \
# count           1095            1090     1095       1095     21          1095
# unique             2              19        4          2      1            62
# ...

# %%
# Count the number of missing (null) values
df.isnull().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
df.drop('method',axis=1,inplace=True)

# %%
df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
# Display the column names
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'umpire1', 'umpire2'],
#       dtype='object')

# %%
 #Total number of matches
total_matches = len(df)
print(f"\nTotal matches: {total_matches}")
# Out:
# Total matches: 1095

# %%
# Unique seasons and their count
unique_seasons = df['season'].nunique()
print(f"Unique seasons: {unique_seasons}")
# Out:
# Unique seasons: 17

# %%
# Most common player_of_match
most_player_awards = df['player_of_match'].value_counts().idxmax()
print(f"Player with most awards: {most_player_awards}")
# Out:
# Player with most awards: AB de Villiers

# %%
# Toss decisions analysis
toss_decision_counts = df['toss_decision'].value_counts()
print(f"\nToss decisions:\n{toss_decision_counts}")
# Out:
# Toss decisions:
# toss_decision
# field    704
# bat      391
# Name: count, dtype: int64

# %%
# Team that won the most tosses
most_toss_wins = df['toss_winner'].value_counts().idxmax()
print(f"Team with most toss wins: {most_toss_wins}")
# Out:
# Team with most toss wins: Mumbai Indians

# %%
# Team with most match wins
most_match_wins = df['winner'].value_counts().idxmax()
print(f"Team with most match wins: {most_match_wins}")
# Out:
# Team with most match wins: Mumbai Indians

# %%
# Count matches played at each venue
venue_counts = df['venue'].value_counts()
venue_counts
# Out:
# venue
# Eden Gardens                                                             77
# Wankhede Stadium                                                         73
# M Chinnaswamy Stadium                                                    65
# Feroz Shah Kotla                                                         60
# Rajiv Gandhi International Stadium, Uppal                                49
# MA Chidambaram Stadium, Chepauk                                          48
# Sawai Mansingh Stadium                                                   47
# Dubai International Cricket Stadium                                      46
# Wankhede Stadium, Mumbai                                                 45
# Punjab Cricket Association Stadium, Mohali                               35
# Sheikh Zayed Stadium                                                     29
# Sharjah Cricket Stadium                                                  28
# ...

# %%
# Most popular venues
most_popular_venues = venue_counts.head(10)
most_popular_venues
# Out:
# venue
# Eden Gardens                                  77
# Wankhede Stadium                              73
# M Chinnaswamy Stadium                         65
# Feroz Shah Kotla                              60
# Rajiv Gandhi International Stadium, Uppal     49
# MA Chidambaram Stadium, Chepauk               48
# Sawai Mansingh Stadium                        47
# Dubai International Cricket Stadium           46
# Wankhede Stadium, Mumbai                      45
# Punjab Cricket Association Stadium, Mohali    35
# Name: count, dtype: int64

# %%
# Most common match venue
most_common_venue = df['venue'].value_counts().idxmax()
print(f"Most common venue: {most_common_venue}")
# Out:
# Most common venue: Eden Gardens

# %%
# Analyze result margins
largest_margin = df['result_margin'].max()
print(f"\nLargest win margin: {largest_margin} runs")
# Out:
# Largest win margin: 146.0 runs

# %%
# Analyze result margins
largest_margin = df['result_margin'].max()
largest_margin_match = df[df['result_margin'] == largest_margin]
print(f"\nLargest win margin: {largest_margin} runs")
print("Match details:")
print(largest_margin_match)
# Out:
# Largest win margin: 146.0 runs
# Match details:
#           id season   city        date match_type player_of_match  \
# 620  1082635   2017  Delhi  2017-05-06     League     LMP Simmons
#
#                 venue             team1           team2       toss_winner  \
# 620  Feroz Shah Kotla  Delhi Daredevils  Mumbai Indians  Delhi Daredevils
#
#     toss_decision          winner result  result_margin  target_runs  \
# 620         field  Mumbai Indians   runs          146.0        213.0
#
#      target_overs super_over      umpire1    umpire2
# 620          20.0          N  Nitin Menon  CK Nandan

# %%
# Get the unique values in the 'target_runs' column
df.target_runs.unique()
# Out:
# array([223., 241., 130., 166., 111., 167., 143., 209., 215., 183., 136.,
#        148., 155., 159., 179., 138., 192., 165., 197., 170., 157., 163.,
#        110., 127., 145., 104., 188., 141., 182., 205., 144., 134., 195.,
#         68.,  89., 198.,  53., 190., 176., 177., 212., 175., 146., 123.,
#        222., 193., 113., 164.,  54., 102., 180.,  69., 185., 151., 169.,
#        150., 140., 120., 149., 142., 154., 106., 187., 117., 158., 124.,
#        174., 121., 161., 135., 189., 171., 147., 162., 213., 191., 204.,
#        219.,  93., 186., 152., 172., 137., 156., 184., 181., 178., 173.,
#        247., 201., 160., 139., 112., 131., 133.,  83.,  96.,  82., 119.,
#        196., 232.,  95., 206.,  52., 126.,  98., 233., 153., 199.,  nan,
#        129., 194., 116., 132., 125., 208., 101., 115., 216., 100., 210.,
#        118., 264.,  81., 224., 107.,  71.,  43., 202., 227., 200., 128.,
#        168., 236., 114., 203., 122.,  99., 228.,  61., 249.,  66., 207.,
# ...

# %%
# Count the occurrences of each unique value in the 'target_runs' column
df.target_runs.value_counts()
# Out:
# target_runs
# 172.0    21
# 166.0    21
# 165.0    20
# 188.0    20
# 163.0    19
#          ..
# 66.0      1
# 104.0     1
# 58.0      1
# 231.0     1
# 242.0     1
# Name: count, Length: 170, dtype: int64

# %%
# Insights based on the target_runs column
average_target_runs = df['target_runs'].mean()
print(f"\nAverage target runs: {average_target_runs}")
# Out:
# Average target runs: 165.68406593406593

# %%
# Season-wise match counts
season_match_counts = df['season'].value_counts()
print(f"\nMatches per season:\n{season_match_counts}")
# Out:
# Matches per season:
# season
# 2013       76
# 2023       74
# 2012       74
# 2022       74
# 2011       73
# 2024       71
# 2018       60
# 2021       60
# 2020/21    60
# 2019       60
# 2016       60
# 2014       60
# 2009/10    60
# 2017       59
# 2015       59
# 2007/08    58
# 2009       57
# Name: count, dtype: int64

# %%
#only display the particular column of the dataset.
df.city
# Out:
# 0        Bangalore
# 1       Chandigarh
# 2            Delhi
# 3           Mumbai
# 4          Kolkata
#            ...
# 1090     Hyderabad
# 1091     Ahmedabad
# 1092     Ahmedabad
# 1093       Chennai
# 1094       Chennai
# Name: city, Length: 1095, dtype: object

# %%
# City-wise match counts
city_match_counts = df['city'].value_counts()
print(f"\nMatches per city:\n{city_match_counts}")
# Out:
# Matches per city:
# city
# Mumbai            173
# Kolkata            93
# Delhi              90
# Chennai            85
# Hyderabad          77
# Bangalore          65
# Chandigarh         61
# Jaipur             57
# Pune               51
# Abu Dhabi          37
# Ahmedabad          36
# Bengaluru          29
# Durban             15
# Visakhapatnam      15
# Lucknow            14
# Dubai              13
# Dharamsala         13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Indore              9
# Navi Mumbai         9
# Johannesburg        8
# Cuttack             7
# Port Elizabeth      7
# Ranchi              7
# Cape Town           7
# Raipur              6
# Mohali              5
# Kochi               5
# Kanpur              4
# Kimberley           3
# East London         3
# Guwahati            3
# Nagpur              3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
# Umpires involved
unique_umpires = pd.concat([df['umpire1'], df['umpire2']]).nunique()
print(f"\nTotal unique umpires: {unique_umpires}")
# Out:
# Total unique umpires: 70

# %%
# Calculate the mean of the 'result_margin' column
result_margin_mean=df['result_margin'].mean()
print(result_margin_mean)
# Out:
# 17.259293680297397

# %%
# Calculate the mean of the 'result_margin' column
result_margin_mean = df['result_margin'].mean()
df['result_margin'].map(lambda p: p - result_margin_mean)# Subtract the mean from each value in the 'result_margin' column
# Out:
# 0       122.740706
# 1        15.740706
# 2        -8.259294
# 3       -12.259294
# 4       -12.259294
#            ...
# 1090    -13.259294
# 1091     -9.259294
# 1092    -13.259294
# 1093     18.740706
# 1094     -9.259294
# Name: result_margin, Length: 1095, dtype: float64

# %%
# Combine team1 and team2 with a hyphen
df.team1+"-"+df.team2
# Out:
# 0       Royal Challengers Bangalore-Kolkata Knight Riders
# 1                     Kings XI Punjab-Chennai Super Kings
# 2                       Delhi Daredevils-Rajasthan Royals
# 3              Mumbai Indians-Royal Challengers Bangalore
# 4                   Kolkata Knight Riders-Deccan Chargers
#                               ...
# 1090                     Punjab Kings-Sunrisers Hyderabad
# 1091            Sunrisers Hyderabad-Kolkata Knight Riders
# 1092                                 RCB-Rajasthan Royals
# 1093                 Sunrisers Hyderabad-Rajasthan Royals
# 1094            Sunrisers Hyderabad-Kolkata Knight Riders
# Length: 1095, dtype: object

# %%
# Calculate the mean of 'target_runs' for each 'team1'
df.groupby('team1').target_runs.mean()
# Out:
# team1
# Chennai Super Kings            170.773438
# Deccan Chargers                160.666667
# Delhi Capitals                 173.097561
# Delhi Daredevils               159.809524
# Gujarat Lions                  166.875000
# Gujarat Titans                 177.714286
# Kings XI Punjab                166.032609
# Kochi Tuskers Kerala           145.571429
# Kolkata Knight Riders          161.975207
# Lucknow Super Giants           182.363636
# Mumbai Indians                 167.317073
# Pune Warriors                  146.652174
# Punjab Kings                   169.096774
# RCB                            196.333333
# Rajasthan Royals               164.613861
# Rising Pune Supergiant         163.571429
# Rising Pune Supergiants        153.142857
# Royal Challengers Bangalore    165.567164
# Sunrisers Hyderabad            162.593023
# Name: target_runs, dtype: float64

# %%
# Calculate the count, minimum, and maximum of 'target_runs' for each 'team1'
df.groupby('team1').target_runs.agg([len,min,max])
# Out:
# <ipython-input-119-e851a061064e>:2: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby('team1').target_runs.agg([len,min,max])
# <ipython-input-119-e851a061064e>:2: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby('team1').target_runs.agg([len,min,max])
#                              len    min    max
# team1
# Chennai Super Kings          128   98.0  247.0
# Deccan Chargers               39  102.0  215.0
# Delhi Capitals                41  111.0  258.0
# Delhi Daredevils              85   43.0  232.0
# Gujarat Lions                 16  125.0  214.0
# Gujarat Titans                21   90.0  234.0
# ...

# %%
 # Set the 'venue' column as the index
df.set_index("venue")
# Out:
#                                                          id   season  \
# venue
# M Chinnaswamy Stadium                                335982  2007/08
# Punjab Cricket Association Stadium, Mohali           335983  2007/08
# Feroz Shah Kotla                                     335984  2007/08
# Wankhede Stadium                                     335985  2007/08
# Eden Gardens                                         335986  2007/08
# ...                                                     ...      ...
# Rajiv Gandhi International Stadium, Uppal, Hyde...  1426307     2024
# Narendra Modi Stadium, Ahmedabad                    1426309     2024
# Narendra Modi Stadium, Ahmedabad                    1426310     2024
# MA Chidambaram Stadium, Chepauk, Chennai            1426311     2024
# MA Chidambaram Stadium, Chepauk, Chennai            1426312     2024
#
#                                                           city        date  \
# venue
# ...

# %%
# Filter rows where the 'city' column is 'Mumbai'
df.loc[df.city == "Mumbai"]
# Out:
#            id   season    city        date match_type player_of_match  \
# 3      335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# 12     335994  2007/08  Mumbai  2008-04-27     League    AC Gilchrist
# 22     336004  2007/08  Mumbai  2008-05-04     League      SM Pollock
# 26     336008  2007/08  Mumbai  2008-05-07     League         A Nehra
# 35     336018  2007/08  Mumbai  2008-05-14     League   ST Jayasuriya
# ...       ...      ...     ...         ...        ...             ...
# 1048  1426263     2024  Mumbai  2024-04-11     League       JJ Bumrah
# 1052  1426267     2024  Mumbai  2024-04-14     League     M Pathirana
# 1074  1426289     2024  Mumbai  2024-05-03     League         VR Iyer
# 1078  1426293     2024  Mumbai  2024-05-06     League        SA Yadav
# 1088  1426305     2024  Mumbai  2024-05-17     League        N Pooran
#
#                            venue                  team1  \
# 3               Wankhede Stadium         Mumbai Indians
# ...

# %%
# Filter rows where the 'city' column is either 'Mumbai' or 'Kolkata'
df.loc[df.city.isin(['Mumbai','Kolkata'])]
# Out:
#            id   season     city        date match_type player_of_match  \
# 3      335985  2007/08   Mumbai  2008-04-20     League      MV Boucher
# 4      335986  2007/08  Kolkata  2008-04-20     League       DJ Hussey
# 12     335994  2007/08   Mumbai  2008-04-27     League    AC Gilchrist
# 15     335997  2007/08  Kolkata  2008-04-29     League   ST Jayasuriya
# 22     336004  2007/08   Mumbai  2008-05-04     League      SM Pollock
# ...       ...      ...      ...         ...        ...             ...
# 1070  1426285     2024  Kolkata  2024-04-29     League        CV Varun
# 1074  1426289     2024   Mumbai  2024-05-03     League         VR Iyer
# 1078  1426293     2024   Mumbai  2024-05-06     League        SA Yadav
# 1083  1426298     2024  Kolkata  2024-05-11     League        CV Varun
# 1088  1426305     2024   Mumbai  2024-05-17     League        N Pooran
#
#                            venue                  team1  \
# 3               Wankhede Stadium         Mumbai Indians
# ...
