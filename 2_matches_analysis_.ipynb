# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\User\OneDrive - AISSMS Institute of Information Technology\Desktop\IPL Infographics\matches.csv")

# %%
df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
# Count matches played at each venue
venue_counts = df['venue'].value_counts()
venue_counts
# Out:
# venue
# Eden Gardens                                                             77
# Wankhede Stadium                                                         73
# M Chinnaswamy Stadium                                                    65
# Feroz Shah Kotla                                                         60
# Rajiv Gandhi International Stadium, Uppal                                49
# MA Chidambaram Stadium, Chepauk                                          48
# Sawai Mansingh Stadium                                                   47
# Dubai International Cricket Stadium                                      46
# Wankhede Stadium, Mumbai                                                 45
# Punjab Cricket Association Stadium, Mohali                               35
# Sheikh Zayed Stadium                                                     29
# Sharjah Cricket Stadium                                                  28
# ...

# %%
# Most popular venues
most_popular_venues = venue_counts.head(10)
most_popular_venues
# Out:
# venue
# Eden Gardens                                  77
# Wankhede Stadium                              73
# M Chinnaswamy Stadium                         65
# Feroz Shah Kotla                              60
# Rajiv Gandhi International Stadium, Uppal     49
# MA Chidambaram Stadium, Chepauk               48
# Sawai Mansingh Stadium                        47
# Dubai International Cricket Stadium           46
# Wankhede Stadium, Mumbai                      45
# Punjab Cricket Association Stadium, Mohali    35
# Name: count, dtype: int64

# %%
# Match outcome analysis
match_outcomes = df['result'].value_counts()
match_outcomes
# Out:
# result
# wickets      578
# runs         498
# tie           14
# no result      5
# Name: count, dtype: int64

# %%
#Bar Chart: Matches per Venue
venue_counts.plot(kind='bar', figsize=(12, 6), title='Matches Played at Each Venue')
plt.xlabel('Venue')
plt.ylabel('Number of Matches')
plt.show()

# %%
# Most popular venues
most_popular_venues.plot(kind='bar', figsize=(12, 6), title='Matches Played at Each Venue')
plt.xlabel('Venue')
plt.ylabel('Number of Matches')
plt.show()

# %%
def calc_count(column_name):
  match_in_city = df[column_name].value_counts()
  return match_in_city

# %%
match_in_city = calc_count("city")
match_in_city = match_in_city.reset_index()
match_in_city.columns=["city","match_count"]
match_in_city.head(5)
# Out:
#         city  match_count
# 0     Mumbai          173
# 1    Kolkata           93
# 2      Delhi           90
# 3    Chennai           85
# 4  Hyderabad           77

# %%
import matplotlib.pyplot as plt
import pdb

def pie_plot(match_data,top_cities):

  columns_header_list = match_data.columns.tolist()
  match_data = match_data.sort_values(by="match_count",ascending =False)
  top_data = match_data.head(top_cities)
  input_data = top_data["match_count"]

  plt.figure(figsize=(12,12))
  # pdb.set_trace()

  # input_data.plot.pie(autopct ="%1.1f%%",startangle=140,cmap ="virdis",explode=[0.05]*len(input_data),labels =top_data[columns_header_list][0])
  input_data.plot.pie(autopct='%1.1f%%', startangle=140, cmap='viridis', explode=[0.05] * len(input_data),labels=top_data[columns_header_list[0]])

  plt.title("total Matchs held in Each state",fontsize =14)
  plt.ylabel("")
  plt.show()

# %%
pie_plot(match_in_city,10)

# %%
win_data = df[df["winner"].notna()]

wins_per_team_at_venue = win_data.groupby(["venue","winner"]).size().reset_index(name="Wins")

wins_per_team_at_venue.head(5)
# Out:
#                   venue               winner  Wins
# 0  Arun Jaitley Stadium  Chennai Super Kings     1
# 1  Arun Jaitley Stadium       Delhi Capitals     4
# 2  Arun Jaitley Stadium     Delhi Daredevils     4
# 3  Arun Jaitley Stadium      Kings XI Punjab     1
# 4  Arun Jaitley Stadium       Mumbai Indians     1

# %%
def most_wins_at_venue(matche_data,venue_name):
  venue_ = matche_data[matche_data["venue"]==venue_name]
  most_wins_team = venue_.loc[venue_["Wins"].idxmax()]
  return most_wins_team["winner"], most_wins_team["Wins"]

# %%
# venue_name = "Arun Jaitley Stadium"
venue_name ="Zayed Cricket Stadium, Abu Dhabi"
team , wins = most_wins_at_venue(wins_per_team_at_venue, venue_name)
print(team , wins )
# wins_per_team_at_venue
# Out:
# Kolkata Knight Riders 2

# %%
def bar_plot(match_data, venue_name):
  venue_ = match_data[match_data["venue"] == venue_name]
  team_wins = venue_.groupby("winner")["Wins"].sum().sort_values(ascending=False)

  plt.figure(figsize=(10,6))
  team_wins.plot(kind ='bar',color="skyblue")
  plt.title(f"number of wins for Each team at {venue_name}",fontsize =14)
  plt.xlabel("Team",fontsize =12)
  plt.ylabel("Number od wins",fontsize =12)
  plt.xticks(rotation=45,ha="right")
  plt.tight_layout()
  plt.show()

# %%
bar_plot(wins_per_team_at_venue,venue_name )

# %%
sns.countplot(x='team1', data=df)  # Bar plot showing the count of occurrences of each 'team1'
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.title('Count of Matches by Team1')
plt.show()

# %%
#Shows the distribution of numerical data
plt.hist(df['target_runs'], bins=20, color='skyblue', edgecolor='black')  # Histogram for 'target_runs'
plt.title('Distribution of Target Runs')
plt.xlabel('Target Runs')
plt.ylabel('Frequency')
plt.show()

# %%
plt.scatter(df['target_runs'], df['result_margin'], color='purple')  # Scatter plot between 'target_runs' and 'result_margin'
plt.title('Target Runs vs Result Margin')
plt.xlabel('Target Runs')
plt.ylabel('Result Margin')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x=df.index, y='target_runs', data=df, color='green')
plt.title('Line Plot of Target Runs Over Matches')
plt.xlabel('Matches')
plt.ylabel('Target Runs')
plt.show()

# %% [markdown]
# Team wise matches outcome in different venues

# %%
matches_won_by_team_venue = df.groupby(['venue', 'winner']).size().unstack(fill_value=0)
matches_won_by_team_venue
# Out:
# winner                                              Chennai Super Kings  \
# venue
# Arun Jaitley Stadium                                                  1
# Arun Jaitley Stadium, Delhi                                           2
# Barabati Stadium                                                      0
# Barsapara Cricket Stadium, Guwahati                                   0
# Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cr...                    0
# Brabourne Stadium                                                     1
# Brabourne Stadium, Mumbai                                             0
# Buffalo Park                                                          1
# De Beers Diamond Oval                                                 1
# Dr DY Patil Sports Academy                                            3
# Dr DY Patil Sports Academy, Mumbai                                    3
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...                    2
# ...

# %%
plt.figure(figsize=(16, 10))
matches_won_by_team_venue.plot(kind='bar', stacked=True, figsize=(16, 10), colormap='tab20c')
plt.title('Total Number of Matches Won by Each Team at Each Venue')
plt.xlabel('Venue')
plt.ylabel('Number of Matches Won')
plt.legend(title='Team', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# Team-Wise Match Outcomes in Different Venues

# %%
matches_by_city = df['city'].value_counts()
matches_by_city
# Out:
# city
# Mumbai            173
# Kolkata            93
# Delhi              90
# Chennai            85
# Hyderabad          77
# Bangalore          65
# Chandigarh         61
# Jaipur             57
# Pune               51
# Abu Dhabi          37
# Ahmedabad          36
# Bengaluru          29
# Visakhapatnam      15
# Durban             15
# Lucknow            14
# Dubai              13
# Dharamsala         13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Navi Mumbai         9
# Indore              9
# Johannesburg        8
# Ranchi              7
# Cuttack             7
# Cape Town           7
# Port Elizabeth      7
# Raipur              6
# Kochi               5
# Mohali              5
# Kanpur              4
# East London         3
# Kimberley           3
# Nagpur              3
# Guwahati            3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
plt.bar(matches_by_city.index, matches_by_city.values, color='skyblue')
plt.xlabel('City')
plt.ylabel('Number of Matches')
plt.title('Number of Matches Played in Each City')
plt.xticks(rotation=90)

for i, value in enumerate(matches_by_city.values):
    plt.text(i, value + 2, str(value), ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
top_10_cities = matches_by_city.head(10)

plt.figure(figsize=(8, 8))
plt.pie(top_10_cities, labels=top_10_cities.index, autopct='%1.1f%%', colors=sns.color_palette("Set3", len(top_10_cities)))
plt.title('Top 10 Cities by Number of Matches')
plt.tight_layout()
plt.show()
